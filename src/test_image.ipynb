# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
image = mpimg.imread('../test_images/test1.jpg')
from detect import *

# %%
output = tracker.car_tracker(image)

# %%
# %matplotlib inline
plt.imshow(output)
