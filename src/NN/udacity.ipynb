# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import glob
path = '/Users/ianzhang/MakerSquare/CarND/CarND-Vehicle-Detection/test_images/*.jpg'

# %%
# mpimg.imread(path)
images = glob.glob(path)
image_0 = mpimg.imread(images[0])
image_0.shape
# Out:
# (720, 1280, 3)

# %%
path_out = '/Users/ianzhang/MakerSquare/squeezeDet/data/out/out_test2.jpg'
print(mpimg.imread(path_out).shape)
# %matplotlib inline
out = mpimg.imread(path_out)
plt.imshow(out)
# Out:
# (375, 1242, 3)

# %%
import cv2
resized = cv2.resize(out, (1280, 720))
resized = cv2.resize(resized, (500, 250))
print(resized.shape)
# Out:
# (250, 500, 3)

# %%
# %matplotlib inline
plt.imshow(resized)
